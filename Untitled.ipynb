# %%
import matplotlib.pyplot as plt
import numpy as np
from IPython.display import clear_output
from qiskit import QuantumCircuit
from qiskit.circuit import Parameter
from qiskit.circuit.library import RealAmplitudes, ZZFeatureMap
from qiskit_algorithms.optimizers import COBYLA, L_BFGS_B
from qiskit_algorithms.utils import algorithm_globals

from qiskit_machine_learning.algorithms.classifiers import NeuralNetworkClassifier, VQC
from qiskit_machine_learning.algorithms.regressors import NeuralNetworkRegressor, VQR
from qiskit_machine_learning.neural_networks import SamplerQNN, EstimatorQNN
from qiskit_machine_learning.circuit.library import QNNCircuit
from qiskit.providers.aer import *
from qiskit import Aer
algorithm_globals.random_seed = 42

# %%
num_inputs = 2
num_samples = 20
X = 2 * algorithm_globals.random.random([num_samples, num_inputs]) - 1
y01 = 1 * (np.sum(X, axis=1) >= 0)  # in { 0,  1}
y = 2 * y01 - 1  # in {-1, +1}
y_one_hot = np.zeros((num_samples, 2))
for i in range(num_samples):
    y_one_hot[i, y01[i]] = 1

for x, y_target in zip(X, y):
    if y_target == 1:
        plt.plot(x[0], x[1], "bo")
    else:
        plt.plot(x[0], x[1], "go")
plt.plot([-1, 1], [1, -1], "--", color="black")
plt.show()

# %%
# construct QNN with the QNNCircuit's default ZZFeatureMap feature map and RealAmplitudes ansatz.
qc = QNNCircuit(num_qubits=2)
qc.draw("mpl")

# %%
backend = AerSimulator(device='GPU')
print(backend)
# Out:
# aer_simulator_gpu

# %%
qc = transpile(qc, backend)
qc.draw('mpl')

# %%
estimator_qnn = EstimatorQNN(circuit=qc)
estimator_qnn.num_inputs
# Out:
# 2

# %%
estimator_qnn = EstimatorQNN(circuit=qc)
# QNN maps inputs to [-1, +1]
estimator_qnn.forward(X[0, :], algorithm_globals.random.random(estimator_qnn.num_weights))
# Out:
# ---------------------------------------------------------------------------
# QiskitMachineLearningError                Traceback (most recent call last)
# Cell In[47], line 3
#       1 estimator_qnn = EstimatorQNN(circuit=qc)
#       2 # QNN maps inputs to [-1, +1]
# ----> 3 estimator_qnn.forward(X[0, :], algorithm_globals.random.random(estimator_qnn.num_weights))
#
# File ~/miniforge3/lib/python3.10/site-packages/qiskit_machine_learning/neural_networks/neural_network.py:224, in NeuralNetwork.forward(self, input_data, weights)
#     209 def forward(
#     210     self,
#     211     input_data: float | list[float] | np.ndarray | None,
#     212     weights: float | list[float] | np.ndarray | None,
#     213 ) -> np.ndarray | SparseArray:
#     214     """Forward pass of the network.
#     215
#     216     Args:
#    (...)
#     222         The result of the neural network of the shape (output_shape).
#     223     """
# --> 224     input_, shape = self._validate_input(input_data)
#     225     weights_ = self._validate_weights(weights)
#     226     output_data = self._forward(input_, weights_)
#
# File ~/miniforge3/lib/python3.10/site-packages/qiskit_machine_learning/neural_networks/neural_network.py:132, in NeuralNetwork._validate_input(self, input_data)
#     129     return input_, shape
#     131 if shape[-1] != self._num_inputs:
# --> 132     raise QiskitMachineLearningError(
#     133         f"Input data has incorrect shape, last dimension "
#     134         f"is not equal to the number of inputs: "
#     135         f"{self._num_inputs}, but got: {shape[-1]}."
#     136     )
#     138 if len(shape) == 1:
#     139     # add an empty dimension for samples (batch dimension)
#     140     input_ = input_.reshape((1, -1))
#
# QiskitMachineLearningError: 'Input data has incorrect shape, last dimension is not equal to the number of inputs: 0, but got: 2.'
